# %%
import pandas as pd
from IPython.display import display, HTML

# %%
import os

# %%
companies = pd.read_csv('companies.csv ')

# %%
companies['permalink']=companies['permalink'].str.lower()
companies['permalink'] = companies['permalink'].str.lstrip('/')
companies['permalink'] = companies['permalink'].str.rstrip('/')
companies['name']=companies['name'].str.lower()

# %%
# companies
companies[companies.duplicated(['name'],keep = False)]
display(companies.describe())
display(companies.isnull().sum())
display(companies.shape[0])
display(companies[companies['name'].isnull()])
# Out:
#                        permalink   name                homepage_url  \
# count                      66368  66367                       61310
# unique                     66368  66037                       61191
# top     organization/bondanddeni  spire  http://www.askforoffer.com
# freq                           1      4                           5
#
#        category_list     status country_code state_code       region  \
# count          63220      66368        59410      57821        58338
# unique         27296          4          137        311         1092
# top         Software  operating          USA         CA  SF Bay Area
# freq            3995      53034        37601      12900         8804
#
#                  city  founded_at
# count           58340       51147
# unique           5111        3978
# top     San Francisco  01-01-2012
# freq             3526        2730
# permalink            0
# name                 1
# homepage_url      5058
# category_list     3148
# ...

# %%
companies
# Out:
#                                                permalink  \
# 0                                     organization/-fame
# 1                                  organization/-qounter
# 2                     organization/-the-one-of-them-inc-
# 3                                   organization/0-6-com
# 4                          organization/004-technologies
# 5                        organization/01games-technology
# 6                     organization/0ndine-biomedical-inc
# 7                                    organization/0xdata
# 8                                         organization/1
# 9                               organization/1-2-3-listo
# 10                                  organization/1-4-all
# 11                         organization/1-618-technology
# 12                            organization/1-800-dentist
# 13                            organization/1-800-doctors
# 14               organization/1-800-publicrelations-inc-
# ...

# %%
round2 = pd.read_csv('rounds2.csv',encoding='ISO-8859-1')

# %%
round2['company_permalink']= round2['company_permalink'].str.lower()
round2['funding_round_permalink']= round2['funding_round_permalink'].str.lower()

# %%
round2.head(5)
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /organization/-qounter
# 2               /organization/-qounter
# 3  /organization/-the-one-of-them-inc-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %%
round2['company_permalink']=round2['company_permalink'].str.lower()
round2['company_permalink']=round2['company_permalink'].str.lstrip('/')
round2['company_permalink']=round2['company_permalink'].str.rstrip('/')

# %%
round2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 6 columns):
# company_permalink          114949 non-null object
# funding_round_permalink    114949 non-null object
# funding_round_type         114949 non-null object
# funding_round_code         31140 non-null object
# funded_at                  114949 non-null object
# raised_amount_usd          94959 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 5.3+ MB

# %%
round2.isnull().sum()
# Out:
# company_permalink              0
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code         83809
# funded_at                      0
# raised_amount_usd          19990
# dtype: int64

# %%
round2['funding_round_permalink'].describe()
# Out:
# count                                              114949
# unique                                             114949
# top       /funding-round/f4625f94def90915298aeccbd32f1af0
# freq                                                    1
# Name: funding_round_permalink, dtype: object

# %%
round2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 6 columns):
# company_permalink          114949 non-null object
# funding_round_permalink    114949 non-null object
# funding_round_type         114949 non-null object
# funding_round_code         31140 non-null object
# funded_at                  114949 non-null object
# raised_amount_usd          94959 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 5.3+ MB

# %%
companies.isnull().sum()
# Out:
# permalink            0
# name                 1
# homepage_url      5058
# category_list     3148
# status               0
# country_code      6958
# state_code        8547
# region            8030
# city              8028
# founded_at       15221
# dtype: int64

# %%
companies = companies[companies.status !='closed']
companies.info()
companies['name'].nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60130 entries, 0 to 66367
# Data columns (total 10 columns):
# permalink        60130 non-null object
# name             60130 non-null object
# homepage_url     55791 non-null object
# category_list    57935 non-null object
# status           60130 non-null object
# country_code     54823 non-null object
# state_code       53365 non-null object
# region           53851 non-null object
# city             53853 non-null object
# founded_at       47065 non-null object
# dtypes: object(10)
# memory usage: 5.0+ MB
# 59866

# %%
companies['permalink'].nunique()
# Out:
# 60130

# %%
companies['category_list'].isnull().sum()
# Out:
# 2195

# %%
companies['category_list'].nunique()
# Out:
# 25053

# %%
display(companies[companies['category_list'].isnull()])
# Out:
#                                      permalink                        name  \
# 56                    organization/123feng-com                 123feng.com
# 71                          organization/15fen                       15fen
# 79                       organization/17-media                    17 media
# 109                       organization/1mxians                     1mxians
# 113                     organization/1rp-media                   1rp media
# 120               organization/1v1-draft-gaems             1v1 draft gaems
# 122                    organization/2-ladoshki                  2 ladoshki
# 154                         organization/24fab                       24fab
# 171                        organization/29west                      29west
# 173                     organization/2b-angels                   2b angels
# 258                      organization/3d-forms                    3d forms
# ...

# %%
companies.isnull().all(axis=1).sum()
# Out:
# 0

# %%
round2.isnull().all(axis=1).sum()
round2.nunique()
# Out:
# company_permalink           66370
# funding_round_permalink    114949
# funding_round_type             14
# funding_round_code              8
# funded_at                    5033
# raised_amount_usd           22095
# dtype: int64

# %%
import numpy as np

# %%
companies=companies[companies['category_list'].notnull()]

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57935 entries, 0 to 66367
# Data columns (total 10 columns):
# permalink        57935 non-null object
# name             57935 non-null object
# homepage_url     54155 non-null object
# category_list    57935 non-null object
# status           57935 non-null object
# country_code     53520 non-null object
# state_code       52105 non-null object
# region           52573 non-null object
# city             52575 non-null object
# founded_at       45993 non-null object
# dtypes: object(10)
# memory usage: 4.9+ MB

# %%
companies['name'].nunique()
# Out:
# 57701

# %%
companies['category_list'].nunique()
# Out:
# 25053

# %%
companies.describe()
# Out:
#                        permalink   name                homepage_url  \
# count                      57935  57935                       54155
# unique                     57935  57701                       54062
# top     organization/bondanddeni  blink  http://www.askforoffer.com
# freq                           1      4                           5
#
#        category_list     status country_code state_code       region  \
# count          57935      57935        53520      52105        52573
# unique         25053          3          134        307         1068
# top         Software  operating          USA         CA  SF Bay Area
# freq            3669      50972        33934      11570         7929
#
#                  city  founded_at
# count           52575       45993
# unique           4807        3751
# top     San Francisco  01-01-2012
# freq             3184        2559

# %%
master_frame = pd.merge(companies,round2,left_on= 'permalink',right_on='company_permalink',how = 'left' )

# %%
master_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103837 entries, 0 to 103836
# Data columns (total 16 columns):
# permalink                  103837 non-null object
# name                       103837 non-null object
# homepage_url               99109 non-null object
# category_list              103837 non-null object
# status                     103837 non-null object
# country_code               97980 non-null object
# state_code                 95917 non-null object
# region                     96639 non-null object
# city                       96642 non-null object
# founded_at                 87197 non-null object
# company_permalink          103826 non-null object
# funding_round_permalink    103826 non-null object
# funding_round_type         103826 non-null object
# funding_round_code         28651 non-null object
# funded_at                  103826 non-null object
# raised_amount_usd          87260 non-null float64
# dtypes: float64(1), object(15)
# memory usage: 13.5+ MB

# %% [markdown]
# master_frame.head(10)

# %%
master_frame['name'].isnull().sum()
# Out:
# 0

# %%
master_frame.isnull().sum()
# Out:
# permalink                      0
# name                           0
# homepage_url                4728
# category_list                  0
# status                         0
# country_code                5857
# state_code                  7920
# region                      7198
# city                        7195
# founded_at                 16640
# company_permalink             11
# funding_round_permalink       11
# funding_round_type            11
# funding_round_code         75186
# funded_at                     11
# raised_amount_usd          16577
# dtype: int64

# %% [markdown]
# master_frame['permalink'].nunique()

# %%
display(master_frame[master_frame['company_permalink'].isnull()])
# Out:
#                                permalink                 name  \
# 2423           organization/adslinkedâ„¢         adslinkedâ„¢
# 7350          organization/asiansbookâ„¢        asiansbookâ„¢
# 29911            organization/etool-ioâ”           etool.ioâ”
# 44675      organization/inveno-è‹±å¨è¯º     inveno è‹±å¨è¯º
# 48355        organization/knowâ€™nâ€™act       knowâ€™nâ€™act
# 48968                organization/kã–ã–k               kã–ã–k
# 49114   organization/lagou-com-æ‹‰å‹¾ç½‘  lagou.com æ‹‰å‹¾ç½‘
# 88116       organization/talentsignedâ„¢      talentsignedâ„¢
# 95235       organization/vacation-bnbâ„¢      vacation bnbâ„¢
# 99845     organization/whodatâ€™s-spaces    whodatâ€™s spaces
# 103835             organization/ã”asys-2               ã”asys
#
#                        homepage_url  \
# 2423       http://www.adslinked.com
# 7350      http://www.asiansbook.com
# 29911           http://www.eTool.io
# 44675          http://www.inveno.cn
# ...

# %%
master_frame =master_frame[master_frame['company_permalink'].notnull()]

# %%
display(master_frame.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103826 entries, 0 to 103836
# Data columns (total 16 columns):
# permalink                  103826 non-null object
# name                       103826 non-null object
# homepage_url               99099 non-null object
# category_list              103826 non-null object
# status                     103826 non-null object
# country_code               97976 non-null object
# state_code                 95913 non-null object
# region                     96635 non-null object
# city                       96638 non-null object
# founded_at                 87192 non-null object
# company_permalink          103826 non-null object
# funding_round_permalink    103826 non-null object
# funding_round_type         103826 non-null object
# funding_round_code         28651 non-null object
# funded_at                  103826 non-null object
# raised_amount_usd          87260 non-null float64
# dtypes: float64(1), object(15)
# memory usage: 13.5+ MB
# ...

# %%
companies[companies['name']=='karma']
# Out:
#                      permalink   name          homepage_url  \
# 30215       organization/karma  karma   http://getkarma.com
# 30216     organization/karma-2  karma  http://yourkarma.com
# 30217     organization/karma-5  karma   https://karma.wiki/
# 30219  organization/karma-labs  karma  http://havekarma.com
#
#                                            category_list     status  \
# 30215                                             Mobile   acquired
# 30216  Internet Service Providers|Mobile|Telecommunic...  operating
# 30217              Media|Social Network Media|Technology  operating
# 30219               Collaborative Consumption|Reputation  operating
#
#       country_code state_code         region           city  founded_at
# 30215          USA         CA    SF Bay Area  San Francisco  01-01-2011
# 30216          USA         NY  New York City       New York  18-01-2012
# 30217          NaN        NaN            NaN            NaN         NaN
# ...

# %%
companies['mix']=companies[['name','category_list']].fillna('').sum(axis=1)

# %%
master_frame
# Out:
#                                                 permalink  \
# 0                                      organization/-fame
# 1                                   organization/-qounter
# 2                                   organization/-qounter
# 3                      organization/-the-one-of-them-inc-
# 4                                    organization/0-6-com
# 5                           organization/004-technologies
# 6                         organization/01games-technology
# 7                      organization/0ndine-biomedical-inc
# 8                      organization/0ndine-biomedical-inc
# 9                                     organization/0xdata
# 10                                    organization/0xdata
# 11                                    organization/0xdata
# 12                                    organization/0xdata
# 13                                         organization/1
# 14                                         organization/1
# ...

# %%
master_frame = master_frame[master_frame['raised_amount_usd'].notnull()]

# %%
master_frame
# Out:
#                                                 permalink  \
# 0                                      organization/-fame
# 2                                   organization/-qounter
# 3                      organization/-the-one-of-them-inc-
# 4                                    organization/0-6-com
# 6                         organization/01games-technology
# 7                      organization/0ndine-biomedical-inc
# 8                      organization/0ndine-biomedical-inc
# 9                                     organization/0xdata
# 10                                    organization/0xdata
# 11                                    organization/0xdata
# 12                                    organization/0xdata
# 13                                         organization/1
# 15                                         organization/1
# 16                               organization/1-2-3-listo
# 20                             organization/1-800-doctors
# ...

# %%
master_frame=master_frame[master_frame['raised_amount_usd'].between(5000000,15000000,inclusive=True)]

# %%
master_frame = master_frame[master_frame['country_code'].notnull()]

# %%
mapping = pd.read_csv('mapping.csv')
aggregate = master_frame.groupby('funding_round_type')
m= aggregate['raised_amount_usd'].mean()
m.sort_values(ascending=False)
# Out:
# funding_round_type
# non_equity_assistance    1.500000e+07
# private_equity           9.328611e+06
# post_ipo_equity          9.315371e+06
# product_crowdfunding     9.268046e+06
# post_ipo_debt            9.045888e+06
# venture                  8.904240e+06
# undisclosed              8.548733e+06
# grant                    8.451716e+06
# debt_financing           8.266821e+06
# secondary_market         8.102816e+06
# convertible_note         8.066782e+06
# angel                    7.312135e+06
# seed                     6.599802e+06
# equity_crowdfunding      6.599428e+06
# Name: raised_amount_usd, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 8))

# plt.subplot(1, 1, 1)
sns.barplot(x='funding_round_type', y='raised_amount_usd', data=master_frame,order = ["venture","angel","seed","private_equity"])
plt.show()

# %%
# master_frame = master_frame.groupby('funding_round_type')
master_frame.describe()
# Out:
#        raised_amount_usd
# count       1.677700e+04
# mean        8.843862e+06
# std         3.063965e+06
# min         5.000000e+06
# 25%         6.000000e+06
# 50%         8.142817e+06
# 75%         1.100000e+07
# max         1.500000e+07

# %%
file = pd.read_excel('Country-withEnglishSpeaking.xlsx')

# %%
file['Code'].describe()
# Out:
# count     239
# unique    239
# top       LBY
# freq        1
# Name: Code, dtype: object

# %%
file= file[file['Code'].notnull()]

# %%
file= file[['Code','Name','English_Official']]
file
# Out:
#     Code                                  Name English_Official
# 1    ABW                                 Aruba                N
# 2    AFG                           Afghanistan                N
# 3    AGO                                Angola                N
# 4    AIA                              Anguilla                N
# 5    ALB                               Albania                N
# 6    AND                               Andorra                N
# 7    ANT                  Netherlands Antilles                N
# 8    ARE                  United Arab Emirates                N
# 9    ARG                             Argentina                N
# 10   ARM                               Armenia                N
# 11   ASM                        American Samoa                N
# 12   ATA                            Antarctica                N
# 13   ATF           French Southern territories                N
# 14   ATG                   Antigua and Barbuda                Y
# ...

# %%
master_frame1 = pd.merge(master_frame,file, left_on='country_code',right_on = 'Code',how='left')
master_frame1
# Out:
#                                      permalink                         name  \
# 0                           organization/-fame                        #fame
# 1                          organization/0xdata                       h2o.ai
# 2      organization/1-800-publicrelations-inc-  1-800-publicrelations, inc.
# 3                    organization/1-mainstream                 1 mainstream
# 4                      organization/1001-menus                      zenchef
# 5              organization/1001pharmacies-com           1001pharmacies.com
# 6                         organization/1006-tv                      1006.tv
# 7                  organization/128-technology               128 technology
# 8               organization/1366-technologies            1366 technologies
# 9               organization/1366-technologies            1366 technologies
# 10              organization/1366-technologies            1366 technologies
# ...

# %%
master_frame1=master_frame1[master_frame1['Name'].notnull()]
master_frame1
# Out:
#                                      permalink                         name  \
# 0                           organization/-fame                        #fame
# 1                          organization/0xdata                       h2o.ai
# 2      organization/1-800-publicrelations-inc-  1-800-publicrelations, inc.
# 3                    organization/1-mainstream                 1 mainstream
# 4                      organization/1001-menus                      zenchef
# 5              organization/1001pharmacies-com           1001pharmacies.com
# 6                         organization/1006-tv                      1006.tv
# 7                  organization/128-technology               128 technology
# 8               organization/1366-technologies            1366 technologies
# 9               organization/1366-technologies            1366 technologies
# 10              organization/1366-technologies            1366 technologies
# ...

# %%
master_frame2=master_frame1[master_frame1['English_Official']=='Y']

# %%
master_frame2
# Out:
#                                      permalink                         name  \
# 0                           organization/-fame                        #fame
# 1                          organization/0xdata                       h2o.ai
# 2      organization/1-800-publicrelations-inc-  1-800-publicrelations, inc.
# 3                    organization/1-mainstream                 1 mainstream
# 7                  organization/128-technology               128 technology
# 8               organization/1366-technologies            1366 technologies
# 9               organization/1366-technologies            1366 technologies
# 10              organization/1366-technologies            1366 technologies
# 11              organization/1366-technologies            1366 technologies
# 12              organization/1366-technologies            1366 technologies
# 13                    organization/170-systems                  170 systems
# ...

# %%
top = master_frame2[master_frame2['funding_round_type']=='venture']

# %%
top['Code'].isnull().sum()
# Out:
# 0

# %% [raw]
# plt.figure(figsize=(14, 8))
# sns.barplot(x='', y='Name', data=master_frame,order = ["venture","angel","seed","private_equity"])
# plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 8))
sns.barplot(x='raised_amount_usd', y='Name', data=top,estimator=sum)
plt.show()

# %%
top9=master_frame1[master_frame1['funding_round_type']=='venture']
top9=master_frame1.groupby('Name')[['raised_amount_usd']].sum().reset_index()
top9=top9.sort_values(['raised_amount_usd'],ascending=False).head(9)
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14,10))
sns.barplot(x='raised_amount_usd', y='Name', data=top9,estimator=sum)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14,10))
sns.barplot(x='raised_amount_usd', y='Name', data=top9,estimator=sum)
plt.show()

# %%
mapping = pd.read_csv('mapping.csv')
mapping=mapping.replace(0, mapping.replace([0], ['0']))
mapping= mapping.drop('Blanks', 1)
mapping
# Out:
#                   category_list Automotive & Sports  \
# 0                           NaN                   0
# 1                            3D                   0
# 2                   3D Printing                   0
# 3                 3D Technology                   0
# 4                    Accounting                   0
# 5              Active Lifestyle                   0
# 6                  Ad Targeting                   0
# 7            Advanced Materials                   0
# 8              Adventure Travel                   1
# 9                   Advertising                   0
# 10        Advertising Exchanges                   0
# 11         Advertising Networks                   0
# 12        Advertising Platforms                   0
# 13                       Advice                   0
# 14                    Aerospace                   1
# 15                  Agriculture                   0
# 16        Air Pollution Control                   0
# ...

# %%
mapping=mapping.loc[:, 'category_list':'Social, Finance, Analytics, Advertising'].replace(1, pd.Series(mapping.columns,mapping.columns))
# mapping['Sum'] =  mapping['Automotive & Sports'] +mapping['Cleantech / Semiconductors']+mapping['Entertainment']+mapping['Health']+mapping['Manufacturing']+mapping['News, Search and Messaging']+|mapping['Others']+mapping['Social, Finance, Analytics, Advertising']
# mapping['Sum'] = mapping.sum(axis=1).astype(str)
# mapping['new'] = mapping[:,'Automotive & Sports':'Social, Finance, Analytics, Advertising'].apply(''.join, axis=1)
# mapping['Sum'] = pd.Series(mapping.fillna('').values.tolist()).str.join('')
mapping['Sum'] = pd.Series(mapping[['Automotive & Sports', 'Cleantech / Semiconductors','Entertainment','Health','Manufacturing','News, Search and Messaging','Others','Social, Finance, Analytics, Advertising']].fillna('').values.tolist()).str.join('')
mapping['Sum'] = mapping['Sum'].str.extract('([a-zA-Z ]+)', expand=False).str.strip()
mapping = mapping[mapping['Sum'].notnull()]
mapping = mapping.drop(['Automotive & Sports','Cleantech / Semiconductors','Entertainment','Health','Manufacturing','News, Search and Messaging','Others','Social, Finance, Analytics, Advertising'],axis=1)
mapping
# Out:
#                           category_list            Sum
# 1                                    3D  Manufacturing
# 2                           3D Printing  Manufacturing
# 3                         3D Technology  Manufacturing
# 4                            Accounting         Social
# 5                      Active Lifestyle         Health
# 6                          Ad Targeting         Social
# 7                    Advanced Materials  Manufacturing
# 8                      Adventure Travel     Automotive
# 9                           Advertising         Social
# 10                Advertising Exchanges         Social
# 11                 Advertising Networks         Social
# 12                Advertising Platforms         Social
# 13                               Advice         Others
# 14                            Aerospace     Automotive
# 15                          Agriculture  Manufacturing
# 16                Air Pollution Control      Cleantech
# ...

# %%
top9.describe()
# Out:
#        raised_amount_usd
# count       9.000000e+00
# mean        1.551537e+10
# std         3.697574e+10
# min         7.237904e+08
# 25%         2.036476e+09
# 50%         3.095525e+09
# 75%         5.046967e+09
# max         1.140183e+11

# %%
# top
top['category_list'] = top['category_list'].str.split('|',expand=True)
top
# Out:
# D:\downloads\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                   permalink                     name  \
# 0                        organization/-fame                    #fame
# 1                       organization/0xdata                   h2o.ai
# 3                 organization/1-mainstream             1 mainstream
# 7               organization/128-technology           128 technology
# 8            organization/1366-technologies        1366 technologies
# 9            organization/1366-technologies        1366 technologies
# 10           organization/1366-technologies        1366 technologies
# 11           organization/1366-technologies        1366 technologies
# ...

# %%
mapping
# Out:
#                           category_list            Sum
# 1                                    3D  Manufacturing
# 2                           3D Printing  Manufacturing
# 3                         3D Technology  Manufacturing
# 4                            Accounting         Social
# 5                      Active Lifestyle         Health
# 6                          Ad Targeting         Social
# 7                    Advanced Materials  Manufacturing
# 8                      Adventure Travel     Automotive
# 9                           Advertising         Social
# 10                Advertising Exchanges         Social
# 11                 Advertising Networks         Social
# 12                Advertising Platforms         Social
# 13                               Advice         Others
# 14                            Aerospace     Automotive
# 15                          Agriculture  Manufacturing
# 16                Air Pollution Control      Cleantech
# ...

# %%
top = pd.merge(top,mapping, left_on='category_list',right_on = 'category_list',how='left')

# %%
top
# Out:
#                                   permalink                     name  \
# 0                        organization/-fame                    #fame
# 1                       organization/0xdata                   h2o.ai
# 2                 organization/1-mainstream             1 mainstream
# 3               organization/128-technology           128 technology
# 4            organization/1366-technologies        1366 technologies
# 5            organization/1366-technologies        1366 technologies
# 6            organization/1366-technologies        1366 technologies
# 7            organization/1366-technologies        1366 technologies
# 8            organization/1366-technologies        1366 technologies
# 9                  organization/170-systems              170 systems
# 10                     organization/17zuoye                  17zuoye
# 11                     organization/17zuoye                  17zuoye
# 12                     organization/1stdibs                  1stdibs
# ...

# %%
D1 = top[top['Name']=='United States']
D1 = D1[D1['Sum'].notnull()]
count1 = D1.groupby('Sum')[['raised_amount_usd']].count().reset_index()
sum1= D1.groupby('Sum')[['raised_amount_usd']].sum().reset_index()
count1
D2 = top[top['Name']=='United Kingdom']
D2 = D2[D2['Sum'].notnull()]
count2 = D2.groupby('Sum')[['raised_amount_usd']].count().reset_index()
sum2= D2.groupby('Sum')[['raised_amount_usd']].sum().reset_index()
D2
D3 = top[top['Name']=='Canada']

D3 = D3[D3['Sum'].notnull()]
count3 = D3.groupby('Sum')[['raised_amount_usd']].count().reset_index()
sum3= D3.groupby('Sum')[['raised_amount_usd']].sum().reset_index()
D3
# Out:
#                                    permalink                      name  \
# 23                    organization/2catalyze                 2catalyze
# 33            organization/360incentives-com         360incentives.com
# 63                        organization/500px                     500px
# 64                        organization/500px                     500px
# 72                   organization/6n-silicon                6n silicon
# 129           organization/accedian-networks         accedian networks
# 202                    organization/acquisio                  acquisio
# 376     organization/aegera-therapeutics-inc       aegera therapeutics
# 429               organization/agile-systems             agile systems
# 466                     organization/aimetis                   aimetis
# 549               organization/alegro-health             alegro health
# 558     organization/alethia-biotherapeutics   alethia biotherapeutics
# ...

# %%
m1_USA= pd.merge(count1, sum1, how='inner', on='Sum')
m2_UK = pd.merge(count2,sum2,how='inner',on='Sum')
m3_Canada = pd.merge(count3,sum3,how='inner',on='Sum')

# %%
m1_USA['raised_amount_usd_x'].sum()
# Out:
# 10404

# %%
m3_Canada['raised_amount_usd_x'].sum()
# Out:
# 361

# %%
m2_UK['raised_amount_usd_x'].sum()
# Out:
# 542

# %%
m1_USA['raised_amount_usd_y'].sum()
# Out:
# 93176222534.0

# %%
m3_Canada['raised_amount_usd_y'].sum()
# Out:
# 3100755116.0

# %%
m2_UK['raised_amount_usd_y'].sum()
# Out:
# 4728734985.0

# %%
m1_USA[m1_USA['raised_amount_usd_x']==m1_USA['raised_amount_usd_x'].max()]
# Out:
#       Sum  raised_amount_usd_x  raised_amount_usd_y
# 6  Others                 2732         2.441447e+10

# %%
m1_USA[m1_USA['raised_amount_usd_y']==m1_USA['raised_amount_usd_y'].max()]
# Out:
#       Sum  raised_amount_usd_x  raised_amount_usd_y
# 6  Others                 2732         2.441447e+10

# %%
m2_UK[m2_UK['raised_amount_usd_x']==m2_UK['raised_amount_usd_x'].max()]
# Out:
#       Sum  raised_amount_usd_x  raised_amount_usd_y
# 6  Others                  137         1.189442e+09

# %%
m2_UK[m2_UK['raised_amount_usd_y']==m2_UK['raised_amount_usd_y'].max()]
# Out:
#       Sum  raised_amount_usd_x  raised_amount_usd_y
# 6  Others                  137         1.189442e+09

# %%
m3_Canada[m3_Canada['raised_amount_usd_x']==m3_Canada['raised_amount_usd_x'].max()]
# Out:
#          Sum  raised_amount_usd_x  raised_amount_usd_y
# 1  Cleantech                   99          894427439.0
# 6     Others                   99          853207962.0

# %%
m1_USA.sort_values('raised_amount_usd_x')
# Out:
#              Sum  raised_amount_usd_x  raised_amount_usd_y
# 0     Automotive                  157         1.374304e+09
# 2  Entertainment                  520         4.503765e+09
# 4  Manufacturing                  739         6.700079e+09
# 3         Health                  853         7.733830e+09
# 5           News                 1445         1.281416e+10
# 7         Social                 1813         1.590572e+10
# 1      Cleantech                 2145         1.972990e+10
# 6         Others                 2732         2.441447e+10

# %%
m2_UK.sort_values('raised_amount_usd_x')
# Out:
#              Sum  raised_amount_usd_x  raised_amount_usd_y
# 0     Automotive                   16         1.670516e+08
# 3         Health                   23         2.025375e+08
# 4  Manufacturing                   40         3.433243e+08
# 2  Entertainment                   51         4.422411e+08
# 5           News                   66         5.585007e+08
# 7         Social                   95         7.976084e+08
# 1      Cleantech                  114         1.028029e+09
# 6         Others                  137         1.189442e+09

# %%
m3_Canada.sort_values('raised_amount_usd_x')
# Out:
#              Sum  raised_amount_usd_x  raised_amount_usd_y
# 0     Automotive                    2           15000000.0
# 3         Health                   17          143960390.0
# 2  Entertainment                   20          143062068.0
# 4  Manufacturing                   30          222633071.0
# 5           News                   44          406121113.0
# 7         Social                   50          422343073.0
# 1      Cleantech                   99          894427439.0
# 6         Others                   99          853207962.0

# %%
count1
# Out:
#              Sum  raised_amount_usd
# 0     Automotive                157
# 1      Cleantech               2145
# 2  Entertainment                520
# 3         Health                853
# 4  Manufacturing                739
# 5           News               1445
# 6         Others               2732
# 7         Social               1813

# %%
D11=D1[D1['Sum']=='Others']
D111=D11.groupby('name')[['raised_amount_usd']].sum().reset_index()
# D111 = D111.groupby('name')[['raised_amount_usd']].sum().reset_index()
display(D111.sort_values(['raised_amount_usd'],ascending=False).head(2))
# Out:
#                    name  raised_amount_usd
# 1780        virtustream         64300000.0
# 285   capella photonics         54968051.0

# %%
D22=D2[D2['Sum']=='Others']
D222=D22.groupby('name')[['raised_amount_usd']].sum().reset_index()
D222.sort_values(['raised_amount_usd'],ascending=False).head(2)
# Out:
#               name  raised_amount_usd
# 30  electric cloud         37000000.0
# 82         sensage         36250000.0

# %%
D33=D3[(D3['Sum']=='Others')|(D3['Sum']=='Cleantech')]
D333=D33.groupby('name')[['raised_amount_usd']].sum().reset_index()
D333.sort_values(['raised_amount_usd'],ascending=False).head(2)
# Out:
#                 name  raised_amount_usd
# 49  fresco microchip         48000000.0
# 96            ostara         43152682.0

# %%
DUSA=D1[D1['Sum']=='Cleantech']
D0=DUSA.groupby('name')[['raised_amount_usd']].sum().reset_index()
D0.sort_values(['raised_amount_usd'],ascending=False).head(2)
# Out:
#              name  raised_amount_usd
# 225      biodesix         75300000.0
# 1338  tigo energy         68739496.0

# %%
DUK=D2[D2['Sum']=='Cleantech']
D00=DUK.groupby('name')[['raised_amount_usd']].sum().reset_index()
D00.sort_values(['raised_amount_usd'],ascending=False).head(2)
# Out:
#                  name  raised_amount_usd
# 27        eusa pharma         35600000.0
# 38  horizon discovery         31353719.0

# %%
DCa=D3[D3['Sum']=='News']
D000=DCa.groupby('name')[['raised_amount_usd']].sum().reset_index()
D000.sort_values(['raised_amount_usd'],ascending=False).head(2)
# Out:
#         name  raised_amount_usd
# 9   dayforce         40000000.0
# 20     slyce         31450000.0

# %%
Total_raised_Amount= master_frame['raised_amount_usd'].sum()
master_frame_fraction = master_frame.groupby('funding_round_type')[['raised_amount_usd']].sum().reset_index()
master_frame_fraction['fraction']=master_frame_fraction['raised_amount_usd']/Total_raised_Amount*100
master_frame_fraction
master_frame_avg = master_frame.groupby('funding_round_type')[['raised_amount_usd']].mean().reset_index()
master_frame_final= pd.merge(master_frame_fraction,master_frame_avg,how='inner',on = 'funding_round_type')
master_frame_final
# Out:
#        funding_round_type  raised_amount_usd_x   fraction  raised_amount_usd_y
# 0                   angel         4.533524e+08   0.305548         7.312135e+06
# 1        convertible_note         3.630052e+08   0.244656         8.066782e+06
# 2          debt_financing         6.563856e+09   4.423874         8.266821e+06
# 3     equity_crowdfunding         1.319886e+08   0.088957         6.599428e+06
# 4                   grant         1.276209e+09   0.860133         8.451716e+06
# 5   non_equity_assistance         1.500000e+07   0.010110         1.500000e+07
# 6           post_ipo_debt         2.713766e+08   0.182901         9.045888e+06
# 7         post_ipo_equity         1.266890e+09   0.853852         9.315371e+06
# 8          private_equity         3.535543e+09   2.382868         9.328611e+06
# 9    product_crowdfunding         1.204846e+08   0.081204         9.268046e+06
# 10       secondary_market         3.241126e+07   0.021844         8.102816e+06
# ...

# %%
plt.figure(num=None, figsize=(14, 10), dpi=80, facecolor='w', edgecolor='y')

sns.barplot(x='funding_round_type', y='raised_amount_usd_y', hue="fraction", data=master_frame_final, estimator=np.mean,order=["venture","private_equity","angel","seed"])
plt.show()

# %%
count1 = count1.sort_values(['raised_amount_usd'],ascending=False).head(3)
count2 = count2.sort_values(['raised_amount_usd'],ascending=False).head(3)
count3 = count3.sort_values(['raised_amount_usd'],ascending=False).head(3)

plt.figure(num=None, figsize=(12, 8), dpi=100, facecolor='w', edgecolor='k')


plt.subplot(2, 2, 1)
sns.barplot(x='raised_amount_usd',y='Sum',data=count1)
plt.subplot(2, 2, 2)
sns.barplot(x='raised_amount_usd',y='Sum',data=count2)
plt.subplot(2, 2, 3)
sns.barplot(x='raised_amount_usd',y='Sum',data=count3)
